# %% [markdown]
# <a href="https://colab.research.google.com/github/MuhammadHassan667410/160-Days-of-learning-complete-AI/blob/main/Phase%202%20%3A%20Machine%20Learning%2C(Day%2020%20to%2050)/Supervised%20ML(Day%2020%20to%2028)/DecisionTreeClassifierPractice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
data = pd.read_csv('DecisionTreePractice.csv')
data
# Out:
#     Age  Salary  Experience  Location  Purchased
# 0    22   15000           1         1          0
# 1    25   29000           2         0          0
# 2    47   48000          10         1          1
# 3    52   60000          14         1          1
# 4    46   52000          12         0          1
# 5    56   65000          16         1          1
# 6    23   21000           2         1          0
# 7    24   25000           2         0          0
# 8    50   58000          13         0          1
# 9    49   57000          13         1          1
# 10   41   50000          11         0          1
# 11   33   32000           4         1          0
# 12   45   51000          12         1          1
# 13   27   27000           3         0          0
# 14   38   43000           9         1          1

# %%
y = data.Purchased
x = data.drop(['Purchased'], axis = 1)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x_scaled = scaler.fit_transform(x)

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x_scaled, y, test_size=0.2)

# %%
from sklearn.tree import DecisionTreeClassifier
dtc = DecisionTreeClassifier()
dtc.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred = dtc.predict(x_test)
y_pred
# Out:
# array([1, 0, 0])

# %%
from sklearn.metrics import classification_report, confusion_matrix
cf = classification_report(y_test, y_pred)

# %%
print(cf)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         2
#            1       1.00      1.00      1.00         1
#
#     accuracy                           1.00         3
#    macro avg       1.00      1.00      1.00         3
# weighted avg       1.00      1.00      1.00         3

# %%
cm = confusion_matrix(y_test, y_pred)
cm
# Out:
# array([[2, 0],
#        [0, 1]])

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.heatmap(cm, annot=True, cmap="Blues")
plt.title('Confusion Matrix')
plt.show()

# %%
from sklearn import tree
plt.figure(figsize=(7,5))
tree.plot_tree(dtc, feature_names = x.columns, class_names = ['No', 'Yes'])
plt.show()
